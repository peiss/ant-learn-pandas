# %% [markdown]
# ## Pandas计算同比环比指标的2种方法
#
# #### 同比和环比：环比和同比用于描述统计数据的变化情况
# * 环比：表示本次统计段与相连的上次统计段之间的比较。
#     - 比如2010年中国第一季度GDP为G2010Q1亿元，第二季度GDP为G2010Q2亿元，则第二季度GDP环比增长（G2010Q2-G2010Q1/G2010Q1；
# * 同比：即同期相比，表示某个特定统计段今年与去年之间的比较。
#     - 比如2009年中国第一季度GDP为G2009Q1亿元，则2010年第一季度的GDP同比增长为（G2010Q1-G2009Q1/G2009Q1。
#
# <img src="./other_files/tongbi_huanbi.jpg" style="margin-left:0px; "/>
#
#
# 演示步骤：
# 0. 读取连续3年的天气数据
# 1. 使用pandas.Series.diff计算和观察差异值
# 2. 同比环比计算方法1：pandas.Series.pct_change
# 3. 同比环比计算方法2：pandas.Series.shift
# 4. 画图观察统计结果

# %% [markdown]
# ### 0. 读取连续3年的天气数据

# %%
import pandas as pd
# %matplotlib inline

# %%
fpath = "./datas/beijing_tianqi/beijing_tianqi_2017-2019.csv"
df = pd.read_csv(fpath, index_col="ymd", parse_dates=True)

# %%
df.head(3)
# Out:
#            bWendu yWendu tianqi fengxiang fengli  aqi aqiInfo  aqiLevel
# ymd
# 2017-01-01     5℃    -3℃    霾~晴        南风   1-2级  450    严重污染         6
# 2017-01-02     7℃    -6℃    晴~霾        南风   1-2级  246    重度污染         5
# 2017-01-03     5℃    -5℃      霾        南风   1-2级  320    严重污染         6

# %%
# 替换掉温度的后缀℃
df["bWendu"] = df["bWendu"].str.replace("℃", "").astype('int32')

# %%
# 获取新的df，为每个月的平均最高温、平均空气质量
df = df[["bWendu"]].resample("M").mean()

# %%
# 将索引按照日期升序排列
df.sort_index(ascending=True, inplace=True)

# %%
df.head()
# Out:
#                bWendu
# ymd
# 2017-01-31   3.322581
# 2017-02-28   7.642857
# 2017-03-31  14.129032
# 2017-04-30  23.700000
# 2017-05-31  29.774194

# %%
df.plot()

# %% [markdown]
# ### 1. 使用pandas.Series.diff计算和观察差异值
#
# 新值减去旧值
#
# 官方文档：https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.diff.html

# %%
# 每个月和上个月的差值
df["diff_1m"] = df["bWendu"].diff(1)
# 每个月和12个月前的差值
df["diff_12m"] = df["bWendu"].diff(12)

# %%
df.head(20)
# Out:
#                bWendu    diff_1m  diff_12m
# ymd
# 2017-01-31   3.322581        NaN       NaN
# 2017-02-28   7.642857   4.320276       NaN
# 2017-03-31  14.129032   6.486175       NaN
# 2017-04-30  23.700000   9.570968       NaN
# 2017-05-31  29.774194   6.074194       NaN
# 2017-06-30  30.966667   1.192473       NaN
# 2017-07-31  31.612903   0.646237       NaN
# 2017-08-31  30.129032  -1.483871       NaN
# 2017-09-30  27.866667  -2.262366       NaN
# 2017-10-31  17.225806 -10.640860       NaN
# 2017-11-30   9.566667  -7.659140       NaN
# 2017-12-31   4.483871  -5.082796       NaN
# 2018-01-31   1.322581  -3.161290 -2.000000
# 2018-02-28   4.892857   3.570276 -2.750000
# 2018-03-31  14.129032   9.236175  0.000000
# 2018-04-30  20.866667   6.737634 -2.833333
# 2018-05-31  27.935484   7.068817 -1.838710
# 2018-06-30  33.000000   5.064516  2.033333
# 2018-07-31  31.774194  -1.225806  0.161290
# 2018-08-31  30.903226  -0.870968  0.774194

# %% [markdown]
# ### 同比环比计算方法1：pandas.Series.pct_change
#
# pct_change方法直接算好了"(新-旧)/旧"的百分比
#
# 官方文档地址：https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.pct_change.html

# %%
df["bWendu_way1_huanbi"] = df["bWendu"].pct_change(periods=1)
df["bWendu_way1_tongbi"] = df["bWendu"].pct_change(periods=12)

# %%
df.head(20)
# Out:
#                bWendu    diff_1m  diff_12m  bWendu_way1_huanbi  \
# ymd
# 2017-01-31   3.322581        NaN       NaN                 NaN
# 2017-02-28   7.642857   4.320276       NaN            1.300277
# 2017-03-31  14.129032   6.486175       NaN            0.848658
# 2017-04-30  23.700000   9.570968       NaN            0.677397
# 2017-05-31  29.774194   6.074194       NaN            0.256295
# 2017-06-30  30.966667   1.192473       NaN            0.040051
# 2017-07-31  31.612903   0.646237       NaN            0.020869
# 2017-08-31  30.129032  -1.483871       NaN           -0.046939
# 2017-09-30  27.866667  -2.262366       NaN           -0.075089
# 2017-10-31  17.225806 -10.640860       NaN           -0.381849
# 2017-11-30   9.566667  -7.659140       NaN           -0.444632
# 2017-12-31   4.483871  -5.082796       NaN           -0.531303
# 2018-01-31   1.322581  -3.161290 -2.000000           -0.705036
# 2018-02-28   4.892857   3.570276 -2.750000            2.699477
# 2018-03-31  14.129032   9.236175  0.000000            1.887685
# 2018-04-30  20.866667   6.737634 -2.833333            0.476865
# 2018-05-31  27.935484   7.068817 -1.838710            0.338761
# 2018-06-30  33.000000   5.064516  2.033333            0.181293
# 2018-07-31  31.774194  -1.225806  0.161290           -0.037146
# 2018-08-31  30.903226  -0.870968  0.774194           -0.027411
#
#             bWendu_way1_tongbi
# ymd
# 2017-01-31                 NaN
# 2017-02-28                 NaN
# 2017-03-31                 NaN
# 2017-04-30                 NaN
# 2017-05-31                 NaN
# 2017-06-30                 NaN
# 2017-07-31                 NaN
# 2017-08-31                 NaN
# 2017-09-30                 NaN
# 2017-10-31                 NaN
# 2017-11-30                 NaN
# 2017-12-31                 NaN
# 2018-01-31           -0.601942
# 2018-02-28           -0.359813
# 2018-03-31            0.000000
# 2018-04-30           -0.119550
# 2018-05-31           -0.061755
# 2018-06-30            0.065662
# 2018-07-31            0.005102
# 2018-08-31            0.025696

# %% [markdown]
# ### 同比环比计算方法2：pandas.Series.shift
#
# shift用于移动数据，但是保持索引不变
#
# 官方文档地址：https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.shift.html

# %%
pd.concat(
    [df["bWendu"], 
     df["bWendu"].shift(periods=1), 
     df["bWendu"].shift(periods=12)],
    axis=1
).head(20)
# Out:
#                bWendu     bWendu     bWendu
# ymd
# 2017-01-31   3.322581        NaN        NaN
# 2017-02-28   7.642857   3.322581        NaN
# 2017-03-31  14.129032   7.642857        NaN
# 2017-04-30  23.700000  14.129032        NaN
# 2017-05-31  29.774194  23.700000        NaN
# 2017-06-30  30.966667  29.774194        NaN
# 2017-07-31  31.612903  30.966667        NaN
# 2017-08-31  30.129032  31.612903        NaN
# 2017-09-30  27.866667  30.129032        NaN
# 2017-10-31  17.225806  27.866667        NaN
# 2017-11-30   9.566667  17.225806        NaN
# 2017-12-31   4.483871   9.566667        NaN
# 2018-01-31   1.322581   4.483871   3.322581
# 2018-02-28   4.892857   1.322581   7.642857
# 2018-03-31  14.129032   4.892857  14.129032
# 2018-04-30  20.866667  14.129032  23.700000
# 2018-05-31  27.935484  20.866667  29.774194
# 2018-06-30  33.000000  27.935484  30.966667
# 2018-07-31  31.774194  33.000000  31.612903
# 2018-08-31  30.903226  31.774194  30.129032

# %%
# 环比
series_shift1 = df["bWendu"].shift(periods=1)
df["bWendu_way2_huanbi"] = (df["bWendu"]-series_shift1)/series_shift1

# 同比
series_shift2 = df["bWendu"].shift(periods=12)
df["bWendu_way2_tongbi"] = (df["bWendu"]-series_shift2)/series_shift2

# %%
df
# Out:
#                bWendu    diff_1m  diff_12m  bWendu_way1_huanbi  \
# ymd
# 2017-01-31   3.322581        NaN       NaN                 NaN
# 2017-02-28   7.642857   4.320276       NaN            1.300277
# 2017-03-31  14.129032   6.486175       NaN            0.848658
# 2017-04-30  23.700000   9.570968       NaN            0.677397
# 2017-05-31  29.774194   6.074194       NaN            0.256295
# 2017-06-30  30.966667   1.192473       NaN            0.040051
# 2017-07-31  31.612903   0.646237       NaN            0.020869
# 2017-08-31  30.129032  -1.483871       NaN           -0.046939
# 2017-09-30  27.866667  -2.262366       NaN           -0.075089
# 2017-10-31  17.225806 -10.640860       NaN           -0.381849
# 2017-11-30   9.566667  -7.659140       NaN           -0.444632
# 2017-12-31   4.483871  -5.082796       NaN           -0.531303
# 2018-01-31   1.322581  -3.161290 -2.000000           -0.705036
# 2018-02-28   4.892857   3.570276 -2.750000            2.699477
# 2018-03-31  14.129032   9.236175  0.000000            1.887685
# 2018-04-30  20.866667   6.737634 -2.833333            0.476865
# 2018-05-31  27.935484   7.068817 -1.838710            0.338761
# 2018-06-30  33.000000   5.064516  2.033333            0.181293
# 2018-07-31  31.774194  -1.225806  0.161290           -0.037146
# 2018-08-31  30.903226  -0.870968  0.774194           -0.027411
# 2018-09-30  26.033333  -4.869892 -1.833333           -0.157585
# 2018-10-31  18.967742  -7.065591  1.741935           -0.271406
# 2018-11-30  10.966667  -8.001075  1.400000           -0.421825
# 2018-12-31   2.387097  -8.579570 -2.096774           -0.782332
# 2019-01-31   4.161290   1.774194  2.838710            0.743243
# 2019-02-28   5.250000   1.088710  0.357143            0.261628
# 2019-03-31  15.741935  10.491935  1.612903            1.998464
# 2019-04-30  20.900000   5.158065  0.033333            0.327664
# 2019-05-31  29.322581   8.422581  1.387097            0.402994
# 2019-06-30  32.233333   2.910753 -0.766667            0.099267
# 2019-07-31  32.935484   0.702151  1.161290            0.021783
# 2019-08-31  30.387097  -2.548387 -0.516129           -0.077375
# 2019-09-30  29.333333  -1.053763  3.300000           -0.034678
# 2019-10-31  19.225806 -10.107527  0.258065           -0.344575
# 2019-11-30  10.366667  -8.859140 -0.600000           -0.460794
# 2019-12-31   3.870968  -6.495699  1.483871           -0.626595
#
#             bWendu_way1_tongbi  bWendu_way2_huanbi  bWendu_way2_tongbi
# ymd
# 2017-01-31                 NaN                 NaN                 NaN
# 2017-02-28                 NaN            1.300277                 NaN
# 2017-03-31                 NaN            0.848658                 NaN
# 2017-04-30                 NaN            0.677397                 NaN
# 2017-05-31                 NaN            0.256295                 NaN
# 2017-06-30                 NaN            0.040051                 NaN
# 2017-07-31                 NaN            0.020869                 NaN
# 2017-08-31                 NaN           -0.046939                 NaN
# 2017-09-30                 NaN           -0.075089                 NaN
# 2017-10-31                 NaN           -0.381849                 NaN
# 2017-11-30                 NaN           -0.444632                 NaN
# 2017-12-31                 NaN           -0.531303                 NaN
# 2018-01-31           -0.601942           -0.705036           -0.601942
# 2018-02-28           -0.359813            2.699477           -0.359813
# 2018-03-31            0.000000            1.887685            0.000000
# 2018-04-30           -0.119550            0.476865           -0.119550
# 2018-05-31           -0.061755            0.338761           -0.061755
# 2018-06-30            0.065662            0.181293            0.065662
# 2018-07-31            0.005102           -0.037146            0.005102
# 2018-08-31            0.025696           -0.027411            0.025696
# 2018-09-30           -0.065789           -0.157585           -0.065789
# 2018-10-31            0.101124           -0.271406            0.101124
# 2018-11-30            0.146341           -0.421825            0.146341
# 2018-12-31           -0.467626           -0.782332           -0.467626
# 2019-01-31            2.146341            0.743243            2.146341
# 2019-02-28            0.072993            0.261628            0.072993
# 2019-03-31            0.114155            1.998464            0.114155
# 2019-04-30            0.001597            0.327664            0.001597
# 2019-05-31            0.049654            0.402994            0.049654
# 2019-06-30           -0.023232            0.099267           -0.023232
# 2019-07-31            0.036548            0.021783            0.036548
# 2019-08-31           -0.016701           -0.077375           -0.016701
# 2019-09-30            0.126761           -0.034678            0.126761
# 2019-10-31            0.013605           -0.344575            0.013605
# 2019-11-30           -0.054711           -0.460794           -0.054711
# 2019-12-31            0.621622           -0.626595            0.621622

# %% [markdown]
# ### 画图观察统计结果：环比变化曲线 VS 温度变化曲线

# %%
df[["bWendu"]].plot(figsize=(12,3))

# %%
# 环比变化
df[["bWendu_way1_huanbi"]].plot(figsize=(12,3))

# %%
# 环比变化
df[["bWendu_way1_tongbi"]].plot(figsize=(12,3))

# %% [markdown]
# ####
